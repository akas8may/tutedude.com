# %% [markdown]
# import pandas as pd
# path = "/Users/akashkulshrestha/PycharmProjects/tutedude.com/Ass7/forUnderstading.xlsx"
# df = pd.read_excel(path)
# print(df)
#
# # headers=["A1","A2","A3","A4","A5","A6","A7"]
# # df.columns=headers
# df.head(5)
# df.dtypes
# df.describe()

# %%
df.head(5)
# Out:
#    sn   A   B   C   D   E  Lenth
# 0   1   5   3  45   3   4     45
# 1   2   5  34   4   2  23     43
# 2   3   5   3  44  34   5     66
# 3   4  56  45  45   4   4     78
# 4   5  44  45  45  45   5     32

# %%
# Single Feature scaling 
# df['Lenth']= df['Lenth']/df['Lenth'].max()
# min -max
# df['Lenth']= (df['Lenth']-df['Lenth'].min())/ (df['Lenth'].max()-df['Lenth'].min())
# df['Lenth']= (df['Lenth']-df['Lenth'].mean())/df['Lenth'].std()
df.head(5)
# Out:
#    sn   A   B   C   D   E  Lenth
# 0   1   5   3  45   3   4     45
# 1   2   5  34   4   2  23     43
# 2   3   5   3  44  34   5     66
# 3   4  56  45  45   4   4     78
# 4   5  44  45  45  45   5     32

# %%
import numpy as np
bins= np.linspace(min(df['Lenth'] ),max(df['Lenth']),4)
group= ["low", "medium","hight"]
df['Lenth-binned']=pd.cut(df['Lenth'],bins,labels=group,include_lowest=True)
df.head(5)
# Out:
#    sn   A   B   C   D   E  Lenth Lenth-binned
# 0   1   5   3  45   3   4     45       medium
# 1   2   5  34   4   2  23     43       medium
# 2   3   5   3  44  34   5     66        hight
# 3   4  56  45  45   4   4     78        hight
# 4   5  44  45  45  45   5     32          low

# %%
pd.get_dummies(df['Lenth'])
# Out:
#       12     32     43     45     54     66     67     77     78     89
# 0  False  False  False   True  False  False  False  False  False  False
# 1  False  False   True  False  False  False  False  False  False  False
# 2  False  False  False  False  False   True  False  False  False  False
# 3  False  False  False  False  False  False  False  False   True  False
# 4  False   True  False  False  False  False  False  False  False  False
# 5   True  False  False  False  False  False  False  False  False  False
# 6  False  False  False  False   True  False  False  False  False  False
# 7  False  False  False  False  False  False   True  False  False  False
# 8  False  False  False  False  False  False  False   True  False  False
# 9  False  False  False  False  False  False  False  False  False   True

# %%
index= pd.Index(df['Lenth'])
index.value_counts()
# Out:
# Lenth
# 45    1
# 43    1
# 66    1
# 78    1
# 32    1
# 12    1
# 54    1
# 67    1
# 77    1
# 89    1
# Name: count, dtype: int64

# %%
#BOXPLOT

import seaborn as sns
# sns.boxplot(x="Lenth",y="E",data=df)

# %%
# Scatterplot
import matplotlib.pyplot as plt
# x=df["Lenth"]
# y=df["E"]

# plt.scatter(x,y)
# plt.title("Scatterplot")
# plt.xlabel("Lenght")
# plt.ylabel("width")

# %%
import numpy as np
# df.dtypes
grp = df.drop(columns=["Lenth-binned"]).groupby(["A","B"],as_index=False).sum()
print(grp)
# df2 = df.drop(columns=["Lenth-binned"])
# grp = df2.groupby("A")
# grp.aggregate(np.sum)
# Out:
#     A   B  sn   C   D   E  Lenth
# 0   3  44  10  45  34  23     89
# 1   4   6   6   2   5  53     12
# 2   4  56   9  45  34   3     77
# 3   5   3   4  89  37   9    111
# 4   5  34   2   4   2  23     43
# 5  44  45   5  45  45   5     32
# 6  46  56   8  23  23   3     67
# 7  54  56   7   2   2   3     54
# 8  56  45   4  45   4   4     78

# %%
grp.size()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[151], line 1
# ----> 1 grp.size()
#
# TypeError: 'int' object is not callable

# %%
l=[["Apple",1],["Apple",2],["Apple",6],["bnana",1],["bnana",1],["bnana",3]]
df_3=pd.DataFrame(l,columns=["A","B"])
print(df_3)
# Out:
#        A  B
# 0  Apple  1
# 1  Apple  2
# 2  Apple  6
# 3  bnana  1
# 4  bnana  1
# 5  bnana  3

# %%
 df_3.groupby("A")["B"].nunique()
# Out:
# A
# Apple    3
# bnana    2
# Name: B, dtype: int64

# %%
df_4=pd.DataFrame({'sn':[1,2,3,4],'A':["A","B","C","D"],'B':["E","F","G","H"],'C':["I","J","K","L"]})
print(df_4)
# Out:
#    sn  A  B  C
# 0   1  A  E  I
# 1   2  B  F  J
# 2   3  C  G  K
# 3   4  D  H  L

# %%
df_4.pivot(index="A",columns="B",values="C")
# Out:
# B    E    F    G    H
# A
# A    I  NaN  NaN  NaN
# B  NaN    J  NaN  NaN
# C  NaN  NaN    K  NaN
# D  NaN  NaN  NaN    L

# %%
df_4.pivot(index="sn",columns="A")["B"]
# Out:
# A     A    B    C    D
# sn
# 1     E  NaN  NaN  NaN
# 2   NaN    F  NaN  NaN
# 3   NaN  NaN    G  NaN
# 4   NaN  NaN  NaN    H

# %%
df_4.pivot(index="sn",columns="A",values=["A","C"])
# Out:
#       A                   C
# A     A    B    C    D    A    B    C    D
# sn
# 1     A  NaN  NaN  NaN    I  NaN  NaN  NaN
# 2   NaN    B  NaN  NaN  NaN    J  NaN  NaN
# 3   NaN  NaN    C  NaN  NaN  NaN    K  NaN
# 4   NaN  NaN  NaN    D  NaN  NaN  NaN    L

# %%
np.random.seed(0)
import seaborn as sns
uniq = np.random.rand(5,6)
normaldata = np.random.randn(6,6)
print(uniq)
print(normaldata)
# Out:
# [[0.5488135  0.71518937 0.60276338 0.54488318 0.4236548  0.64589411]
#  [0.43758721 0.891773   0.96366276 0.38344152 0.79172504 0.52889492]
#  [0.56804456 0.92559664 0.07103606 0.0871293  0.0202184  0.83261985]
#  [0.77815675 0.87001215 0.97861834 0.79915856 0.46147936 0.78052918]
#  [0.11827443 0.63992102 0.14335329 0.94466892 0.52184832 0.41466194]]
# [[ 0.8644362  -0.74216502  2.26975462 -1.45436567  0.04575852 -0.18718385]
#  [ 1.53277921  1.46935877  0.15494743  0.37816252 -0.88778575 -1.98079647]
#  [-0.34791215  0.15634897  1.23029068  1.20237985 -0.38732682 -0.30230275]
#  [-1.04855297 -1.42001794 -1.70627019  1.9507754  -0.50965218 -0.4380743 ]
#  [-1.25279536  0.77749036 -1.61389785 -0.21274028 -0.89546656  0.3869025 ]
#  [-0.51080514 -1.18063218 -0.02818223  0.42833187  0.06651722  0.3024719 ]]

# %%
print(uniq)
heap_map = sns.heatmap(uniq)
# Out:
# [[0.5488135  0.71518937 0.60276338 0.54488318 0.4236548  0.64589411]
#  [0.43758721 0.891773   0.96366276 0.38344152 0.79172504 0.52889492]
#  [0.56804456 0.92559664 0.07103606 0.0871293  0.0202184  0.83261985]
#  [0.77815675 0.87001215 0.97861834 0.79915856 0.46147936 0.78052918]
#  [0.11827443 0.63992102 0.14335329 0.94466892 0.52184832 0.41466194]]

# %%
heap_map2 = sns.heatmap(uniq, vmin=0,vmax=1)

# %%
print(normaldata)
# Out:
# [[ 0.8644362  -0.74216502  2.26975462 -1.45436567  0.04575852 -0.18718385]
#  [ 1.53277921  1.46935877  0.15494743  0.37816252 -0.88778575 -1.98079647]
#  [-0.34791215  0.15634897  1.23029068  1.20237985 -0.38732682 -0.30230275]
#  [-1.04855297 -1.42001794 -1.70627019  1.9507754  -0.50965218 -0.4380743 ]
#  [-1.25279536  0.77749036 -1.61389785 -0.21274028 -0.89546656  0.3869025 ]
#  [-0.51080514 -1.18063218 -0.02818223  0.42833187  0.06651722  0.3024719 ]]

# %%
heat_map3 = sns.heatmap(normaldata,center=0)

# %%
flight= sns.load_dataset("flights")
flight = flight.pivot(index="month", columns="year", values="passengers")
heat_map4= sns.heatmap(flight)

# %%
heat_map5 = sns.heatmap(flight , annot=True,fmt="d")

# %%
heat_map6 = sns.heatmap(flight , cmap="YlGnBu",annot=True,fmt="d")

# %%
heat_map6 = sns.heatmap(flight , cmap="YlGnBu",annot=True,fmt="d" ,cbar=False)

# %%
flight= sns.load_dataset("flights")
sns.regplot(x='passengers',y='year',data=flight)
# Out:
# <Axes: xlabel='passengers', ylabel='year'>

# %%
from scipy import stats
flight= sns.load_dataset("flights")
print(flight)
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
pearson_correlation = stats.pearsonr(flight['year'],flight['passengers'])
print(pearson_correlation)
# Out:
# PearsonRResult(statistic=np.float64(0.9218238352924201), pvalue=np.float64(2.58104255191102e-60))

# %%
# Simple linear regresssion
from sklearn.linear_model import LinearRegression

lm = LinearRegression()
x=flight[["year"]]
y=flight[["passengers"]]
lm.fit(x,y)
# Out:
# LinearRegression()

# %%
Yhat= lm.predict(x)
print(Yhat)
# Out:
# [[104.71688034]
#  [104.71688034]
#  [104.71688034]
#  [104.71688034]
#  [104.71688034]
#  [104.71688034]
#  [104.71688034]
#  [104.71688034]
#  [104.71688034]
#  [104.71688034]
#  [104.71688034]
#  [104.71688034]
#  [136.64083139]
#  [136.64083139]
#  [136.64083139]
#  [136.64083139]
#  [136.64083139]
#  [136.64083139]
#  [136.64083139]
#  [136.64083139]
#  [136.64083139]
#  [136.64083139]
#  [136.64083139]
#  [136.64083139]
#  [168.56478244]
#  [168.56478244]
#  [168.56478244]
#  [168.56478244]
#  [168.56478244]
#  [168.56478244]
#  [168.56478244]
#  [168.56478244]
#  [168.56478244]
#  [168.56478244]
#  [168.56478244]
#  [168.56478244]
#  [200.48873349]
#  [200.48873349]
#  [200.48873349]
#  [200.48873349]
#  [200.48873349]
#  [200.48873349]
#  [200.48873349]
#  [200.48873349]
#  [200.48873349]
#  [200.48873349]
#  [200.48873349]
#  [200.48873349]
#  [232.41268454]
#  [232.41268454]
#  [232.41268454]
#  [232.41268454]
#  [232.41268454]
#  [232.41268454]
#  [232.41268454]
# ...

# %%
lm.intercept_
# Out:
# array([-62115.06371406])

# %%
lm.coef_
# Out:
# array([[31.92395105]])

# %%
# Multiple linear regressing
from sklearn.linear_model import LinearRegression
lm = LinearRegression()

print(df)
# Out:
#    sn   A   B   C   D   E  Lenth Lenth-binned
# 0   1   5   3  45   3   4     45       medium
# 1   2   5  34   4   2  23     43       medium
# 2   3   5   3  44  34   5     66        hight
# 3   4  56  45  45   4   4     78        hight
# 4   5  44  45  45  45   5     32          low
# 5   6   4   6   2   5  53     12          low
# 6   7  54  56   2   2   3     54       medium
# 7   8  46  56  23  23   3     67        hight
# 8   9   4  56  45  34   3     77        hight
# 9  10   3  44  45  34  23     89        hight

# %%
X=df[["A","B","C"]]
Y=df["D"]
lm.fit(X,Y)
# LinearRegression()
# Out:
# LinearRegression()

# %%
Yhat= lm.predict(X)
print(Yhat)
# Out:
# [20.15818516  8.95476803 19.65422389 22.24660488 24.77060323 -0.3864298
#   4.35335411 16.61920643 36.54034869 33.08913539]

# %%
lm.intercept_
lm.coef_
# Out:
# array([-0.2103332 ,  0.30512887,  0.50396127])

# %%
""" Regression plot
vertical-axis = depended
Horizentel-axis= independed"""
# Out:
# ' Regression plot\nvertical-axis = depended\nHorizentel-axis= independed'

# %%
import seaborn as sns
import matplotlib.pyplot as plt
print(flight)
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.regplot(y='passengers',x='year',data=flight)
plt.ylim(0,500)
# Out:
# (0.0, 500.0)

# %%
# residule plot
  # residule value

# %%
sns.residplot(data=flight, x="year", y="passengers")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
np.random.seed(0)
x = np.random.randn(10)
ax_1 = sns.histplot(x,kde=True)

# %%
ax_2 = sns.distplot(x,rug=True,hist=False)
# Out:
# /var/folders/bk/kqgtb74j1_976q8qc_vxlm_c0000gn/T/ipykernel_94460/1904567008.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax_2 = sns.distplot(x,rug=True,hist=False)

# %%
ax_2 = sns.distplot(x,rug=False,hist=True)
# Out:
# /var/folders/bk/kqgtb74j1_976q8qc_vxlm_c0000gn/T/ipykernel_94460/127659574.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax_2 = sns.distplot(x,rug=False,hist=True)

# %%
from scipy.stats import norm
ax_2 = sns.distplot(x,fit=norm )
# Out:
# /var/folders/bk/kqgtb74j1_976q8qc_vxlm_c0000gn/T/ipykernel_94460/3856867795.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax_2 = sns.distplot(x,fit=norm )

# %%
ax_2 = sns.distplot(x,fit=norm, kde=False )
# Out:
# /var/folders/bk/kqgtb74j1_976q8qc_vxlm_c0000gn/T/ipykernel_94460/2729935641.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax_2 = sns.distplot(x,fit=norm, kde=False )
