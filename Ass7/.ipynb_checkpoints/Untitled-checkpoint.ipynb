# %%
import pandas as pd
path = "/Users/akashkulshrestha/PycharmProjects/tutedude.com/Ass7/forUnderstading.xlsx"
df = pd.read_excel(path)
print(df)

# headers=["A1","A2","A3","A4","A5","A6","A7"]
# df.columns=headers
df.head(5)
# df.dtypes
# df.describe()
# Out:
#    sn   A   B   C       D     E  Lenth
# 0   1   5   3  45       3     4     45
# 1   2   5  34   4       2    23     56
# 2   3   5   3  44      34  2323     63
# 3   4  56  45  45       4     4     23
# 4   5  44  45  45      45     5     25
# 5   6   4   6   2  452321    53     17
# 6   7  54  56   2       2     3     70
# 7   8  46  56  23      23     3     90
# 8   9   4  56  45      34     3   1120
# 9  10   3  44  45      34    23      1
#    sn   A   B   C   D     E  Lenth
# 0   1   5   3  45   3     4     45
# 1   2   5  34   4   2    23     56
# 2   3   5   3  44  34  2323     63
# 3   4  56  45  45   4     4     23
# 4   5  44  45  45  45     5     25

# %%
df.head(5)
# Out:
#    sn   A   B   C   D     E  Lenth
# 0   1   5   3  45   3     4     45
# 1   2   5  34   4   2    23     56
# 2   3   5   3  44  34  2323     63
# 3   4  56  45  45   4     4     23
# 4   5  44  45  45  45     5     25

# %%
# Single Feature scaling 
# df['Lenth']= df['Lenth']/df['Lenth'].max()
# min -max
# df['Lenth']= (df['Lenth']-df['Lenth'].min())/ (df['Lenth'].max()-df['Lenth'].min())
# df['Lenth']= (df['Lenth']-df['Lenth'].mean())/df['Lenth'].std()
df.head(5)
# Out:
#    sn   A   B   C   D     E     Lenth
# 0   1   5   3  45   3     4 -0.310342
# 1   2   5  34   4   2    23 -0.278136
# 2   3   5   3  44  34  2323 -0.257642
# 3   4  56  45  45   4     4 -0.374752
# 4   5  44  45  45  45     5 -0.368897

# %%
import numpy as np
bins= np.linspace(min(df['Lenth'] ),max(df['Lenth']),4)
group= ["low", "medium","hight"]
df['Lenth-binned']=pd.cut(df['Lenth'],bins,labels=group,include_lowest=True)
df.head(5)
# Out:
#    sn   A   B   C   D     E     Lenth Lenth-binned
# 0   1   5   3  45   3     4 -0.310342          low
# 1   2   5  34   4   2    23 -0.278136          low
# 2   3   5   3  44  34  2323 -0.257642          low
# 3   4  56  45  45   4     4 -0.374752          low
# 4   5  44  45  45  45     5 -0.368897          low
